# %%
pip install --upgrade nbformat

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig.show()

# %%
# Dependencies and Setup
import seaborn as sns 
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
campus_cvs = "csv_datasets/act-campus-data-class-2022.csv"
campus_df = pd.read_csv(campus_cvs)
campus_df.head()
# Out:
#               Group   Campus  AICode   CampName  District    DistName  County  \
# 0      All Students  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 1  African American  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 2   American Indian  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 3             Asian  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 4          Hispanic  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
#
#           CntyName  Region RegnName  ...  Reading  Science  Compos  \
# 0  Anderson County       7  Kilgore  ...     20.5     25.5    23.0
# 1  Anderson County       7  Kilgore  ...      NaN      NaN     NaN
# 2  Anderson County       7  Kilgore  ...      NaN      NaN     NaN
# 3  Anderson County       7  Kilgore  ...      NaN      NaN     NaN
# 4  Anderson County       7  Kilgore  ...      NaN      NaN     NaN
#
#    Grads_Mskd  Exnees_Mskd Part_Rate Crit_Mskd  Above_Crit_Rate TSI_Both_Mskd  \
# ...

# %%
total_expenditures_csv = "csv_datasets/total-operating-expenditures.csv"
total_expenditures_df = pd.read_csv(total_expenditures_csv)
total_expenditures_df. head()
# Out:
#       CDN       District                                   2005-2006  \
# 0     NaN            NaN  Total  Operating Expenditures, All Funds 1
# 1  001902     CAYUGA ISD                                  $4,419,577
# 2  001903    ELKHART ISD                                  $8,655,605
# 3  001904  FRANKSTON ISD                                  $6,475,854
# 4  001906     NECHES ISD                                  $2,641,035
#
#                  Unnamed: 3                                    Unnamed: 4  \
# 0  Enrollment (membership)2  All Funds Operating Expenditures per Student
# 1                       582                                        $7,594
# 2                     1,294                                        $6,689
# 3                       797                                        $8,125
# 4                       329                                        $8,027
#
#                                     2006-2007                Unnamed: 6  \
# ...

# %%
act_campus_csv = "csv_datasets/act-campus-data-class-2022.csv"
act_campus_df = pd.read_csv(act_campus_csv)
act_campus_df
# Out:
#                             Group     Campus  AICode     CampName  District  \
# 0                    All Students    1902001  441165    Cayuga HS      1902
# 1                African American    1902001  441165    Cayuga HS      1902
# 2                 American Indian    1902001  441165    Cayuga HS      1902
# 3                           Asian    1902001  441165    Cayuga HS      1902
# 4                        Hispanic    1902001  441165    Cayuga HS      1902
# ...                           ...        ...     ...          ...       ...
# 88459                 Not Migrant  254902001  444030  La Pryor HS    254902
# 88460             Missing Migrant  254902001  444030  La Pryor HS    254902
# 88461          Military-Connected  254902001  444030  La Pryor HS    254902
# 88462      Not Military-Connected  254902001  444030  La Pryor HS    254902
# 88463  Missing Military-Connected  254902001  444030  La Pryor HS    254902
#
# ...

# %%
sat_campus_data_csv = "csv_datasets/sat-campus-data-class-2022.csv"
sat_campus_data_df = pd.read_csv(sat_campus_data_csv)
sat_campus_data_df.head()
# Out:
#               Group   Campus  AICode   CampName  District    DistName  County  \
# 0      All Students  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 1  African American  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 2   American Indian  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 3             Asian  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 4          Hispanic  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
#
#           CntyName  Region RegnName    ERW   Math   Total Grads_Mskd  \
# 0  Anderson County       7  Kilgore  513.0  496.0  1009.0        <50
# 1  Anderson County       7  Kilgore    NaN    NaN     NaN        <25
# 2  Anderson County       7  Kilgore    NaN    NaN     NaN        <25
# 3  Anderson County       7  Kilgore    NaN    NaN     NaN        <25
# 4  Anderson County       7  Kilgore  535.0  480.0  1015.0        <25
#
#   Exnees_Mskd  Part_Rate Crit_Mskd  Above_Crit_Rate TSI_Both_Mskd  \
# ...

# %%
dropout_df = pd.read_csv("csv_datasets/dropout_rates.csv")
dropout_df.head()
# Out:
# C:\Users\riahk\AppData\Local\Temp\ipykernel_16424\2116307333.py:1: DtypeWarning: Columns (13,58,67,79,82,85,91,94,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   dropout_df = pd.read_csv("csv_datasets/dropout_rates.csv")
#   CALC_FOR_STATE_ACCT  GRADESPAN   CAMPUS       CAMPNAME  DISTRICT  \
# 0                  No        712  1902001      Cayuga HS      1902
# 1                 Yes        712  1902001      Cayuga HS      1902
# 2                  No        912  1902001      Cayuga HS      1902
# 3                 Yes        912  1902001      Cayuga HS      1902
# 4                  No        712  1902041  Cayuga Middle      1902
#
#      DISTNAME  COUNTY         CNTYNAME  REGION REGNNAME  ... CAMP_SE5R  \
# 0  Cayuga ISD       1  Anderson County       7  Kilgore  ...       0.0
# 1  Cayuga ISD       1  Anderson County       7  Kilgore  ...       0.0
# 2  Cayuga ISD       1  Anderson County       7  Kilgore  ...       0.0
# ...

# %%
campus_merge_df = pd.merge(sat_campus_data_df, act_campus_df, how="left", on=["Campus"])
campus_merge_df.head()
# Out:
#         Group_x   Campus  AICode_x CampName_x  District_x  DistName_x  \
# 0  All Students  1902001    441165  Cayuga HS        1902  Cayuga ISD
# 1  All Students  1902001    441165  Cayuga HS        1902  Cayuga ISD
# 2  All Students  1902001    441165  Cayuga HS        1902  Cayuga ISD
# 3  All Students  1902001    441165  Cayuga HS        1902  Cayuga ISD
# 4  All Students  1902001    441165  Cayuga HS        1902  Cayuga ISD
#
#    County_x       CntyName_x  Region_x RegnName_x  ...  Reading  Science  \
# 0         1  Anderson County         7    Kilgore  ...     20.5     25.5
# 1         1  Anderson County         7    Kilgore  ...      NaN      NaN
# 2         1  Anderson County         7    Kilgore  ...      NaN      NaN
# 3         1  Anderson County         7    Kilgore  ...      NaN      NaN
# 4         1  Anderson County         7    Kilgore  ...      NaN      NaN
#
#    Compos Grads_Mskd_y Exnees_Mskd_y  Part_Rate_y Crit_Mskd_y  \
# ...
