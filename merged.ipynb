# %%
# import seaborn as sns
# import plotly.express as px
# import matplotlib.pyplot as plt
import pandas as pd
# import scipy.stats as st
# import numpy as np
# from scipy.stats import linregress

# %%
financial_df = pd.read_csv("csv_datasets/2007-2022-summarized-peims-financial-data.csv")
financial_df.head()
# Out:
#    DISTRICT NUMBER DISTRICT NAME  YEAR GEN FUNDS-LOCAL TAX REVENUE FROM M&O  \
# 0             1902    CAYUGA ISD  2007                           $4,122,552
# 1             1902    CAYUGA ISD  2008                           $3,641,351
# 2             1902    CAYUGA ISD  2009                           $3,319,164
# 3             1902    CAYUGA ISD  2010                           $3,222,688
# 4             1902    CAYUGA ISD  2011                           $3,152,618
#
#   ALL FUNDS-LOCAL TAX REVENUE FROM M&O GEN FUNDS-STATE REVENUE  \
# 0                           $4,122,552              $1,114,179
# 1                           $3,641,351              $1,845,232
# 2                           $3,319,164              $1,950,169
# 3                           $3,222,688              $2,302,369
# 4                           $3,152,618              $2,439,570
#
#   ALL FUNDS-STATE REVENUE GEN FUNDS-FEDERAL REVENUE ALL FUNDS-FEDERAL REVENUE  \
# ...

# %%
# save: group, district, budget, reading, science, Comopos, 
act_campus_df = pd.read_csv("csv_datasets/act-campus-data-class-2022.csv")
act_campus_df.head()
# Out:
#               Group   Campus  AICode   CampName  District    DistName  County  \
# 0      All Students  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 1  African American  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 2   American Indian  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 3             Asian  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 4          Hispanic  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
#
#           CntyName  Region RegnName  ...  Reading  Science  Compos  \
# 0  Anderson County       7  Kilgore  ...     20.5     25.5    23.0
# 1  Anderson County       7  Kilgore  ...      NaN      NaN     NaN
# 2  Anderson County       7  Kilgore  ...      NaN      NaN     NaN
# 3  Anderson County       7  Kilgore  ...      NaN      NaN     NaN
# 4  Anderson County       7  Kilgore  ...      NaN      NaN     NaN
#
#    Grads_Mskd  Exnees_Mskd Part_Rate Crit_Mskd  Above_Crit_Rate TSI_Both_Mskd  \
# ...

# %%
campus_df = pd.read_csv("csv_datasets/campus-analyze-2021-22.csv")
campus_df.head()
# Out:
#                                        Campus Name     Campus  Campus Type  \
# 0  21ST CENTURY EARLY LEARNING FOUNDATIONS ACADEMY  108913118           21
# 1                          2ND H S IN THE DISTRICT  152906004           41
# 2                                       3D ACADEMY  108902006           21
# 3                                   A & M CONS H S   21901001           12
# 4                        A & M CONSOLIDATED MIDDLE   21901042           12
#
#   Campus Type Description
# 0        21-Suburb: Large
# 1        41-Rural: Fringe
# 2        21-Suburb: Large
# 3       12-City: Mid-size
# 4       12-City: Mid-size

# %%
drop_df = pd.read_csv("csv_datasets/campus-data-download-drop-2122.csv")
drop_df
# Out:
# C:\Users\yama2\AppData\Local\Temp\ipykernel_22120\3987359900.py:1: DtypeWarning: Columns (13,58,67,79,82,85,91,94,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   drop_df = pd.read_csv("csv_datasets/campus-data-download-drop-2122.csv")
#       CALC_FOR_STATE_ACCT  GRADESPAN     CAMPUS       CAMPNAME  DISTRICT  \
# 0                      No        712    1902001      Cayuga HS      1902
# 1                     Yes        712    1902001      Cayuga HS      1902
# 2                      No        912    1902001      Cayuga HS      1902
# 3                     Yes        912    1902001      Cayuga HS      1902
# 4                      No        712    1902041  Cayuga Middle      1902
# ...                   ...        ...        ...            ...       ...
# 18472                 Yes        712  254902001    La Pryor HS    254902
# 18473                  No         78  254902001    La Pryor HS    254902
# ...

# %%
total_expenditures_df = pd.read_csv("csv_datasets/sat-campus-data-class-2022.csv")
total_expenditures_df.head()
# Out:
#               Group   Campus  AICode   CampName  District    DistName  County  \
# 0      All Students  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 1  African American  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 2   American Indian  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 3             Asian  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
# 4          Hispanic  1902001  441165  Cayuga HS      1902  Cayuga ISD       1
#
#           CntyName  Region RegnName    ERW   Math   Total Grads_Mskd  \
# 0  Anderson County       7  Kilgore  513.0  496.0  1009.0        <50
# 1  Anderson County       7  Kilgore    NaN    NaN     NaN        <25
# 2  Anderson County       7  Kilgore    NaN    NaN     NaN        <25
# 3  Anderson County       7  Kilgore    NaN    NaN     NaN        <25
# 4  Anderson County       7  Kilgore  535.0  480.0  1015.0        <25
#
#   Exnees_Mskd  Part_Rate Crit_Mskd  Above_Crit_Rate TSI_Both_Mskd  \
# ...

# %%
total_expenditures_df = pd.read_csv("csv_datasets/total-operating-expenditures.csv")
total_expenditures_df
# Out:
#                                                     CDN       District  \
# 0                                                   NaN            NaN
# 1                                                001902     CAYUGA ISD
# 2                                                001903    ELKHART ISD
# 3                                                001904  FRANKSTON ISD
# 4                                                001906     NECHES ISD
# ...                                                 ...            ...
# 1319                                                NaN    State Total
# 1320                                                NaN            NaN
# 1321  1. Total Operating expenditures All funds are ...            NaN
# 1322                                                NaN            NaN
# 1323  2. Membership is the total number of students ...            NaN
#
#                                        2005-2006                Unnamed: 3  \
# ...
